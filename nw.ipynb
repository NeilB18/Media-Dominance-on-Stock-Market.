# %%
import requests
import pandas as pd
from datetime import date, timedelta

def get_past_month():
    end_date = date.today()
    start_date = end_date - timedelta(days=30)
    return start_date.strftime('%Y-%m-%d'), end_date.strftime('%Y-%m-%d')

def fetch_news():
    api_key = '0198e7f971c8481a8cd87be585211a46'
    base_url = 'https://newsapi.org/v2/everything'
    search_query = 'S&P 500'
    publishers = 'the-new-york-times,the-wall-street-journal,usa-today,the-washington-post,cnbc,financial-times,forbes,business-insider,reuters,bloomberg,the-economist,barrons,marketwatch,morningstar'
    from_date, to_date = get_past_month()
    
    params = {
        'q': search_query,
        'sources': publishers,
        'from': from_date,
        'to': to_date,
        'apiKey': api_key
    }
    
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()['articles']
    else:
        print("Error fetching news:", response.status_code)
        return []

def create_excel(news_data):
    data_list = []
    for article in news_data:
        date_published = article['publishedAt'][:10]
        publisher = article['source']['name']
        headline = article['title']
        data_list.append({'Date': date_published, 'Publisher': publisher, 'Headline': headline})
    df = pd.DataFrame(data_list)
    return df

if __name__ == "__main__":
    news_data = fetch_news()
    if news_data:
        df = create_excel(news_data)
        df.sort_values(by='Date', inplace=True)
        df.to_excel('S&P500_News.xlsx', index=False)
        print("Excel sheet created successfully!")
    else:
        print("No news found for the specified criteria.")
# Out:
# Excel sheet created successfully!

# %%
df = pd.read_excel('S&P500_News.xlsx')
df
# Out:
#           Date         Publisher  \
# 0   2023-06-29  Business Insider
# 1   2023-06-29  Business Insider
# 2   2023-06-29  Business Insider
# 3   2023-06-29  Business Insider
# 4   2023-06-29  Business Insider
# ..         ...               ...
# 95  2023-07-27  Business Insider
# 96  2023-07-28  Business Insider
# 97  2023-07-28  Business Insider
# 98  2023-07-29  Business Insider
# 99  2023-07-29  Business Insider
#
#                                              Headline
# 0   Forget FAANG and GAMMA, the 'Magnificent 7' te...
# 1   US stocks rise after fresh batch of positive e...
# 2   Apple is a great company – but not much is dri...
# 3   US stocks rise as traders digest upbeat econom...
# 4         Americans aren't spending like they used to
# ..                                                ...
# 95  Dow snaps historic win streak as US stocks fal...
# 96  The extreme bubble in stocks 'will end in tear...
# 97  Dow and S&P 500 finish 3rd straight winning we...
# 98  The Dow's latest winning streak is bad news fo...
# 99  The Fed's newfound focus on data is bad news f...
#
# [100 rows x 3 columns]
